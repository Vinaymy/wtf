# %% [markdown]
# This file contains a utility for chopping up an image of variable size into tiles. Choose the tile
# dimensions by trial and error so that they nicely contain a handwritten character.
#
# In order to get started, upload an image of a journal entry to the colab workspace root directory. Then running the utility will create chopped images in a subdirectory called "cropped." There is a second utility to zip the cropped directory and copy it to your google drive. For this you'll need to authenticate your session through a guid.

# %% [markdown]
# First the necessary imports

# %%
import os
from PIL import Image
from google.colab import files
from google.colab import auth
from googleapiclient.http import MediaFileUpload
from googleapiclient.discovery import build

# %% [markdown]
# Utility to crop an image

# %%
def crop(path, input, height, width):
    """ 
    Crops input image into height X width tiles  
    
    Parameters: 
    path (string): Path to the directory where you want the output tiles to be 
    created.
    input (string): Name of image file to be chopped
    height (int): height of output tile
    width (int): width of output tile
    """
    im = Image.open(input)
    imgwidth, imgheight = im.size
    
    k = 1
    y_offset = 0
    
    while y_offset < 1: # height:
      x_offset = 0
      print(y_offset, flush=True)
      while x_offset < 1: # width:
        for i in range(y_offset,imgheight,height):
          for j in range(x_offset,imgwidth,width):
            box = (j, i, j+width, i+height)
            a = im.crop(box)
            extrema = a.convert("L").getextrema()
            if abs(extrema[0] - extrema[1]) >= 100:
                a.save(os.path.join(path,"IMG-%s.png" % k))
                k += 1
        x_offset += 1
      y_offset += 1
      
    print(
        "Successfully chopped {} into {} {}X{} tiles in {} directory".format(
              input, k-1, height, width, path
        )
    )

# %% [markdown]
# Assuming you've uploaded an image file to colab (E.g. "wtf_dec01_2016.png"), let's create a directory called "cropped" to collect the tiles after chopping.

# %%
# !mkdir cropped

# %% [markdown]
# Next we invoke the utility to perform the cropping

# %%
crop("cropped/", "wtf_dec01_2016.png", 25, 20)
# Out:
# 0
# Successfully chopped wtf_dec01_2016.png into 1825 25X20 tiles in cropped/ directory

# %% [markdown]
# Next, let's zip the output directory (E.g. "cropped") and copy to your google drive. It will prompt you to authenticate by walking you through your google account and generating a guid that you'll need to paste below to authenticate, so that it can verify your identity to save the file to your google drive.

# %%
#@title save data to drive
filename = "wtf_dec01_2016" #@param {type:"string"}
folders_or_files_to_save = "cropped" #@param {type:"string"}
def save_to_google_drive(name, path):
    file_metadata = {
    'name': name,
    'mimeType': 'application/octet-stream'
    }

    media = MediaFileUpload(
          path 
        , mimetype='application/octet-stream'
        , resumable=True
    )

    created = drive_service.files().create(
          body=file_metadata
        , media_body=media
        , fields='id'
    ).execute()

    print('File ID: {}'.format(created.get('id')))

    return created

extension_zip = ".zip"
zip_file = filename + extension_zip
# !zip -r $zip_file {folders_or_files_to_save} 
# FOLDERS TO SAVE INTO ZIP FILE

auth.authenticate_user()
drive_service = build('drive', 'v3')

destination_name = zip_file
path_to_file = zip_file
save_to_google_drive(destination_name, path_to_file)
# Out:
#   adding: cropped/ (stored 0%)
#   adding: cropped/IMG-1412.png (stored 0%)
#   adding: cropped/IMG-1073.png (stored 0%)
#   adding: cropped/IMG-382.png (stored 0%)
#   adding: cropped/IMG-86.png (stored 0%)
#   adding: cropped/IMG-1072.png (stored 0%)
#   adding: cropped/IMG-1762.png (stored 0%)
#   adding: cropped/IMG-520.png (stored 0%)
#   adding: cropped/IMG-683.png (stored 0%)
#   adding: cropped/IMG-421.png (stored 0%)
#   adding: cropped/IMG-833.png (stored 0%)
#   adding: cropped/IMG-696.png (stored 0%)
#   adding: cropped/IMG-1271.png (stored 0%)
#   adding: cropped/IMG-1213.png (stored 0%)
#   adding: cropped/IMG-1141.png (stored 0%)
#   adding: cropped/IMG-806.png (stored 0%)
#   adding: cropped/IMG-741.png (stored 0%)
#   adding: cropped/IMG-781.png (stored 0%)
#   adding: cropped/IMG-203.png (stored 0%)
#   adding: cropped/IMG-1036.png (stored 0%)
#   adding: cropped/IMG-378.png (stored 0%)
#   adding: cropped/IMG-162.png (stored 0%)
#   adding: cropped/IMG-852.png (stored 0%)
#   adding: cropped/IMG-794.png (stored 0%)
#   adding: cropped/IMG-402.png (stored 0%)
#   adding: cropped/IMG-1758.png (stored 0%)
#   adding: cropped/IMG-470.png (stored 0%)
#   adding: cropped/IMG-64.png (stored 0%)
#   adding: cropped/IMG-1595.png (stored 0%)
#   adding: cropped/IMG-969.png (stored 0%)
#   adding: cropped/IMG-749.png (stored 0%)
#   adding: cropped/IMG-1719.png (stored 0%)
#   adding: cropped/IMG-1196.png (stored 0%)
#   adding: cropped/IMG-1502.png (stored 0%)
#   adding: cropped/IMG-1004.png (stored 0%)
#   adding: cropped/IMG-563.png (stored 0%)
#   adding: cropped/IMG-1559.png (stored 0%)
#   adding: cropped/IMG-186.png (stored 0%)
#   adding: cropped/IMG-493.png (stored 0%)
#   adding: cropped/IMG-643.png (stored 0%)
#   adding: cropped/IMG-703.png (stored 0%)
#   adding: cropped/IMG-1099.png (stored 0%)
#   adding: cropped/IMG-176.png (stored 0%)
#   adding: cropped/IMG-1325.png (stored 0%)
#   adding: cropped/IMG-1167.png (stored 0%)
#   adding: cropped/IMG-144.png (stored 0%)
#   adding: cropped/IMG-1583.png (stored 0%)
#   adding: cropped/IMG-351.png (stored 0%)
#   adding: cropped/IMG-183.png (stored 0%)
#   adding: cropped/IMG-1278.png (stored 0%)
#   adding: cropped/IMG-397.png (stored 0%)
#   adding: cropped/IMG-914.png (stored 0%)
#   adding: cropped/IMG-1657.png (stored 0%)
#   adding: cropped/IMG-1027.png (stored 0%)
#   adding: cropped/IMG-1663.png (stored 0%)
#   adding: cropped/IMG-918.png (stored 0%)
#   adding: cropped/IMG-1582.png (stored 0%)
#   adding: cropped/IMG-216.png (stored 0%)
#   adding: cropped/IMG-1217.png (stored 0%)
#   adding: cropped/IMG-1473.png (stored 0%)
#   adding: cropped/IMG-201.png (stored 0%)
#   adding: cropped/IMG-1619.png (stored 0%)
#   adding: cropped/IMG-1190.png (stored 0%)
#   adding: cropped/IMG-840.png (stored 0%)
#   adding: cropped/IMG-933.png (stored 0%)
#   adding: cropped/IMG-1405.png (stored 0%)
#   adding: cropped/IMG-995.png (stored 0%)
#   adding: cropped/IMG-217.png (stored 0%)
#   adding: cropped/IMG-1567.png (stored 0%)
#   adding: cropped/IMG-1538.png (stored 0%)
#   adding: cropped/IMG-148.png (stored 0%)
#   adding: cropped/IMG-602.png (stored 0%)
#   adding: cropped/IMG-1009.png (stored 0%)
#   adding: cropped/IMG-1019.png (stored 0%)
#   adding: cropped/IMG-766.png (stored 0%)
#   adding: cropped/IMG-1024.png (stored 0%)
#   adding: cropped/IMG-580.png (stored 0%)
#   adding: cropped/IMG-1674.png (stored 0%)
#   adding: cropped/IMG-1192.png (stored 0%)
#   adding: cropped/IMG-624.png (stored 0%)
#   adding: cropped/IMG-369.png (stored 0%)
#   adding: cropped/IMG-132.png (stored 0%)
#   adding: cropped/IMG-514.png (stored 0%)
#   adding: cropped/IMG-322.png (stored 0%)
#   adding: cropped/IMG-603.png (stored 0%)
#   adding: cropped/IMG-1544.png (stored 0%)
#   adding: cropped/IMG-1258.png (stored 0%)
#   adding: cropped/IMG-442.png (stored 0%)
#   adding: cropped/IMG-73.png (stored 0%)
#   adding: cropped/IMG-227.png (stored 0%)
#   adding: cropped/IMG-429.png (stored 0%)
#   adding: cropped/IMG-688.png (stored 0%)
#   adding: cropped/IMG-1635.png (stored 0%)
#   adding: cropped/IMG-1616.png (stored 0%)
#   adding: cropped/IMG-648.png (stored 0%)
#   adding: cropped/IMG-612.png (stored 0%)
#   adding: cropped/IMG-574.png (stored 0%)
#   adding: cropped/IMG-139.png (stored 0%)
#   adding: cropped/IMG-1558.png (stored 0%)
#   adding: cropped/IMG-348.png (stored 0%)
#   adding: cropped/IMG-556.png (stored 0%)
#   adding: cropped/IMG-1744.png (stored 0%)
#   adding: cropped/IMG-1476.png (stored 0%)
#   adding: cropped/IMG-1795.png (deflated 3%)
#   adding: cropped/IMG-585.png (stored 0%)
#   adding: cropped/IMG-799.png (stored 0%)
#   adding: cropped/IMG-249.png (stored 0%)
#   adding: cropped/IMG-1499.png (stored 0%)
#   adding: cropped/IMG-340.png (stored 0%)
#   adding: cropped/IMG-1425.png (stored 0%)
#   adding: cropped/IMG-359.png (stored 0%)
#   adding: cropped/IMG-1372.png (stored 0%)
#   adding: cropped/IMG-224.png (stored 0%)
#   adding: cropped/IMG-540.png (stored 0%)
#   adding: cropped/IMG-965.png (stored 0%)
#   adding: cropped/IMG-541.png (stored 0%)
#   adding: cropped/IMG-1284.png (stored 0%)
#   adding: cropped/IMG-709.png (stored 0%)
#   adding: cropped/IMG-1820.png (stored 0%)
#   adding: cropped/IMG-60.png (stored 0%)
#   adding: cropped/IMG-1427.png (stored 0%)
#   adding: cropped/IMG-925.png (stored 0%)
#   adding: cropped/IMG-1326.png (stored 0%)
#   adding: cropped/IMG-832.png (stored 0%)
#   adding: cropped/IMG-1339.png (stored 0%)
#   adding: cropped/IMG-822.png (stored 0%)
#   adding: cropped/IMG-215.png (stored 0%)
#   adding: cropped/IMG-636.png (stored 0%)
#   adding: cropped/IMG-757.png (stored 0%)
#   adding: cropped/IMG-135.png (stored 0%)
#   adding: cropped/IMG-1283.png (stored 0%)
#   adding: cropped/IMG-891.png (stored 0%)
#   adding: cropped/IMG-484.png (stored 0%)
#   adding: cropped/IMG-1342.png (stored 0%)
#   adding: cropped/IMG-457.png (stored 0%)
#   adding: cropped/IMG-238.png (stored 0%)
#   adding: cropped/IMG-1168.png (stored 0%)
#   adding: cropped/IMG-596.png (stored 0%)
#   adding: cropped/IMG-1303.png (stored 0%)
#   adding: cropped/IMG-434.png (stored 0%)
#   adding: cropped/IMG-477.png (stored 0%)
#   adding: cropped/IMG-1658.png (stored 0%)
#   adding: cropped/IMG-200.png (stored 0%)
#   adding: cropped/IMG-960.png (stored 0%)
#   adding: cropped/IMG-141.png (stored 0%)
#   adding: cropped/IMG-750.png (stored 0%)
#   adding: cropped/IMG-285.png (stored 0%)
#   adding: cropped/IMG-209.png (stored 0%)
#   adding: cropped/IMG-1360.png (stored 0%)
#   adding: cropped/IMG-1089.png (stored 0%)
#   adding: cropped/IMG-920.png (stored 0%)
#   adding: cropped/IMG-199.png (stored 0%)
#   adding: cropped/IMG-1654.png (stored 0%)
#   adding: cropped/IMG-1753.png (stored 0%)
#   adding: cropped/IMG-251.png (stored 0%)
#   adding: cropped/IMG-687.png (stored 0%)
#   adding: cropped/IMG-1767.png (stored 0%)
#   adding: cropped/IMG-802.png (stored 0%)
#   adding: cropped/IMG-131.png (stored 0%)
#   adding: cropped/IMG-1569.png (stored 0%)
#   adding: cropped/IMG-1407.png (stored 0%)
#   adding: cropped/IMG-1804.png (stored 0%)
#   adding: cropped/IMG-1174.png (stored 0%)
#   adding: cropped/IMG-1397.png (stored 0%)
#   adding: cropped/IMG-43.png (stored 0%)
#   adding: cropped/IMG-1075.png (stored 0%)
#   adding: cropped/IMG-350.png (stored 0%)
#   adding: cropped/IMG-932.png (stored 0%)
#   adding: cropped/IMG-848.png (stored 0%)
#   adding: cropped/IMG-573.png (stored 0%)
#   adding: cropped/IMG-220.png (stored 0%)
#   adding: cropped/IMG-718.png (stored 0%)
#   adding: cropped/IMG-1034.png (stored 0%)
#   adding: cropped/IMG-783.png (stored 0%)
#   adding: cropped/IMG-1387.png (stored 0%)
#   adding: cropped/IMG-1186.png (stored 0%)
#   adding: cropped/IMG-1293.png (stored 0%)
#   adding: cropped/IMG-1158.png (stored 0%)
#   adding: cropped/IMG-1553.png (stored 0%)
#   adding: cropped/IMG-321.png (stored 0%)
#   adding: cropped/IMG-221.png (stored 0%)
#   adding: cropped/IMG-858.png (stored 0%)
#   adding: cropped/IMG-379.png (stored 0%)
#   adding: cropped/IMG-257.png (stored 0%)
#   adding: cropped/IMG-897.png (stored 0%)
#   adding: cropped/IMG-889.png (stored 0%)
#   adding: cropped/IMG-722.png (stored 0%)
#   adding: cropped/IMG-1773.png (stored 0%)
#   adding: cropped/IMG-1801.png (stored 0%)
#   adding: cropped/IMG-1815.png (deflated 1%)
#   adding: cropped/IMG-343.png (stored 0%)
#   adding: cropped/IMG-1162.png (stored 0%)
#   adding: cropped/IMG-1464.png (stored 0%)
#   adding: cropped/IMG-1209.png (stored 0%)
#   adding: cropped/IMG-1296.png (stored 0%)
#   adding: cropped/IMG-780.png (stored 0%)
#   adding: cropped/IMG-46.png (stored 0%)
#   adding: cropped/IMG-864.png (stored 0%)
#   adding: cropped/IMG-841.png (stored 0%)
#   adding: cropped/IMG-338.png (stored 0%)
#   adding: cropped/IMG-427.png (stored 0%)
#   adding: cropped/IMG-142.png (stored 0%)
#   adding: cropped/IMG-1021.png (stored 0%)
#   adding: cropped/IMG-328.png (stored 0%)
#   adding: cropped/IMG-1497.png (stored 0%)
#   adding: cropped/IMG-55.png (stored 0%)
#   adding: cropped/IMG-1816.png (deflated 1%)
#   adding: cropped/IMG-793.png (stored 0%)
#   adding: cropped/IMG-233.png (stored 0%)
#   adding: cropped/IMG-1574.png (stored 0%)
#   adding: cropped/IMG-433.png (stored 0%)
#   adding: cropped/IMG-407.png (stored 0%)
#   adding: cropped/IMG-1220.png (stored 0%)
#   adding: cropped/IMG-1139.png (stored 0%)
#   adding: cropped/IMG-1596.png (stored 0%)
#   adding: cropped/IMG-971.png (stored 0%)
#   adding: cropped/IMG-1272.png (stored 0%)
#   adding: cropped/IMG-1401.png (stored 0%)
#   adding: cropped/IMG-1741.png (stored 0%)
#   adding: cropped/IMG-1536.png (stored 0%)
#   adding: cropped/IMG-272.png (stored 0%)
#   adding: cropped/IMG-88.png (stored 0%)
#   adding: cropped/IMG-1322.png (stored 0%)
#   adding: cropped/IMG-805.png (stored 0%)
#   adding: cropped/IMG-1221.png (stored 0%)
#   adding: cropped/IMG-1534.png (stored 0%)
#   adding: cropped/IMG-1788.png (stored 0%)
#   adding: cropped/IMG-721.png (stored 0%)
#   adding: cropped/IMG-1202.png (stored 0%)
#   adding: cropped/IMG-731.png (stored 0%)
#   adding: cropped/IMG-851.png (stored 0%)
#   adding: cropped/IMG-993.png (stored 0%)
#   adding: cropped/IMG-727.png (stored 0%)
#   adding: cropped/IMG-123.png (stored 0%)
#   adding: cropped/IMG-536.png (stored 0%)
#   adding: cropped/IMG-515.png (stored 0%)
#   adding: cropped/IMG-155.png (stored 0%)
#   adding: cropped/IMG-1065.png (stored 0%)
#   adding: cropped/IMG-1504.png (stored 0%)
#   adding: cropped/IMG-1493.png (stored 0%)
#   adding: cropped/IMG-1509.png (stored 0%)
#   adding: cropped/IMG-2.png (stored 0%)
#   adding: cropped/IMG-586.png (stored 0%)
#   adding: cropped/IMG-1822.png (stored 0%)
#   adding: cropped/IMG-157.png (stored 0%)
#   adding: cropped/IMG-1581.png (stored 0%)
#   adding: cropped/IMG-1512.png (stored 0%)
#   adding: cropped/IMG-1697.png (stored 0%)
#   adding: cropped/IMG-1305.png (stored 0%)
#   adding: cropped/IMG-756.png (stored 0%)
#   adding: cropped/IMG-1618.png (stored 0%)
#   adding: cropped/IMG-1548.png (stored 0%)
#   adding: cropped/IMG-1378.png (stored 0%)
#   adding: cropped/IMG-357.png (stored 0%)
#   adding: cropped/IMG-443.png (stored 0%)
#   adding: cropped/IMG-396.png (stored 0%)
#   adding: cropped/IMG-1312.png (stored 0%)
#   adding: cropped/IMG-1026.png (stored 0%)
#   adding: cropped/IMG-1528.png (stored 0%)
#   adding: cropped/IMG-1572.png (stored 0%)
#   adding: cropped/IMG-304.png (stored 0%)
#   adding: cropped/IMG-674.png (stored 0%)
#   adding: cropped/IMG-456.png (stored 0%)
#   adding: cropped/IMG-1086.png (stored 0%)
#   adding: cropped/IMG-1570.png (stored 0%)
#   adding: cropped/IMG-191.png (stored 0%)
#   adding: cropped/IMG-1777.png (deflated 2%)
#   adding: cropped/IMG-296.png (stored 0%)
#   adding: cropped/IMG-737.png (stored 0%)
#   adding: cropped/IMG-310.png (stored 0%)
#   adding: cropped/IMG-985.png (stored 0%)
#   adding: cropped/IMG-1813.png (stored 0%)
#   adding: cropped/IMG-1806.png (deflated 1%)
#   adding: cropped/IMG-294.png (stored 0%)
#   adding: cropped/IMG-752.png (stored 0%)
#   adding: cropped/IMG-78.png (stored 0%)
#   adding: cropped/IMG-651.png (stored 0%)
#   adding: cropped/IMG-910.png (stored 0%)
#   adding: cropped/IMG-692.png (stored 0%)
#   adding: cropped/IMG-951.png (stored 0%)
#   adding: cropped/IMG-94.png (stored 0%)
#   adding: cropped/IMG-500.png (stored 0%)
#   adding: cropped/IMG-699.png (stored 0%)
#   adding: cropped/IMG-1513.png (stored 0%)
#   adding: cropped/IMG-808.png (stored 0%)
#   adding: cropped/IMG-1660.png (stored 0%)
#   adding: cropped/IMG-939.png (stored 0%)
#   adding: cropped/IMG-708.png (stored 0%)
#   adding: cropped/IMG-1088.png (stored 0%)
#   adding: cropped/IMG-8.png (stored 0%)
#   adding: cropped/IMG-1648.png (stored 0%)
#   adding: cropped/IMG-51.png (stored 0%)
#   adding: cropped/IMG-1154.png (stored 0%)
#   adding: cropped/IMG-1560.png (stored 0%)
#   adding: cropped/IMG-130.png (stored 0%)
#   adding: cropped/IMG-691.png (stored 0%)
#   adding: cropped/IMG-1309.png (stored 0%)
#   adding: cropped/IMG-1218.png (stored 0%)
#   adding: cropped/IMG-1511.png (stored 0%)
#   adding: cropped/IMG-113.png (stored 0%)
#   adding: cropped/IMG-1623.png (stored 0%)
#   adding: cropped/IMG-754.png (stored 0%)
#   adding: cropped/IMG-194.png (stored 0%)
#   adding: cropped/IMG-672.png (stored 0%)
#   adding: cropped/IMG-11.png (stored 0%)
#   adding: cropped/IMG-1673.png (stored 0%)
#   adding: cropped/IMG-1489.png (stored 0%)
#   adding: cropped/IMG-106.png (stored 0%)
#   adding: cropped/IMG-1057.png (stored 0%)
#   adding: cropped/IMG-48.png (stored 0%)
#   adding: cropped/IMG-1642.png (stored 0%)
#   adding: cropped/IMG-807.png (stored 0%)
#   adding: cropped/IMG-860.png (stored 0%)
#   adding: cropped/IMG-1584.png (stored 0%)
#   adding: cropped/IMG-1466.png (stored 0%)
#   adding: cropped/IMG-1323.png (stored 0%)
#   adding: cropped/IMG-1652.png (stored 0%)
#   adding: cropped/IMG-1056.png (stored 0%)
#   adding: cropped/IMG-491.png (stored 0%)
#   adding: cropped/IMG-1730.png (stored 0%)
#   adding: cropped/IMG-17.png (stored 0%)
#   adding: cropped/IMG-1666.png (stored 0%)
#   adding: cropped/IMG-54.png (stored 0%)
#   adding: cropped/IMG-866.png (stored 0%)
#   adding: cropped/IMG-723.png (stored 0%)
#   adding: cropped/IMG-412.png (stored 0%)
#   adding: cropped/IMG-1012.png (stored 0%)
#   adding: cropped/IMG-1738.png (stored 0%)
#   adding: cropped/IMG-154.png (stored 0%)
#   adding: cropped/IMG-439.png (stored 0%)
#   adding: cropped/IMG-1266.png (stored 0%)
#   adding: cropped/IMG-1060.png (stored 0%)
#   adding: cropped/IMG-425.png (stored 0%)
#   adding: cropped/IMG-1739.png (stored 0%)
#   adding: cropped/IMG-482.png (stored 0%)
#   adding: cropped/IMG-290.png (stored 0%)
#   adding: cropped/IMG-90.png (stored 0%)
#   adding: cropped/IMG-80.png (stored 0%)
#   adding: cropped/IMG-1118.png (stored 0%)
#   adding: cropped/IMG-395.png (stored 0%)
#   adding: cropped/IMG-1164.png (stored 0%)
#   adding: cropped/IMG-551.png (stored 0%)
#   adding: cropped/IMG-77.png (stored 0%)
#   adding: cropped/IMG-1261.png (stored 0%)
#   adding: cropped/IMG-266.png (stored 0%)
#   adding: cropped/IMG-652.png (stored 0%)
#   adding: cropped/IMG-315.png (stored 0%)
#   adding: cropped/IMG-1607.png (stored 0%)
#   adding: cropped/IMG-829.png (stored 0%)
#   adding: cropped/IMG-110.png (stored 0%)
#   adding: cropped/IMG-1404.png (stored 0%)
#   adding: cropped/IMG-1058.png (stored 0%)
#   adding: cropped/IMG-1241.png (stored 0%)
#   adding: cropped/IMG-1247.png (stored 0%)
#   adding: cropped/IMG-1686.png (stored 0%)
#   adding: cropped/IMG-1054.png (stored 0%)
#   adding: cropped/IMG-1690.png (stored 0%)
#   adding: cropped/IMG-1496.png (stored 0%)
#   adding: cropped/IMG-1477.png (stored 0%)
#   adding: cropped/IMG-228.png (stored 0%)
#   adding: cropped/IMG-1223.png (stored 0%)
#   adding: cropped/IMG-243.png (stored 0%)
#   adding: cropped/IMG-834.png (stored 0%)
#   adding: cropped/IMG-1415.png (stored 0%)
#   adding: cropped/IMG-89.png (stored 0%)
#   adding: cropped/IMG-690.png (stored 0%)
#   adding: cropped/IMG-959.png (stored 0%)
#   adding: cropped/IMG-1776.png (deflated 1%)
#   adding: cropped/IMG-326.png (stored 0%)
#   adding: cropped/IMG-1498.png (stored 0%)
#   adding: cropped/IMG-345.png (stored 0%)
#   adding: cropped/IMG-1362.png (stored 0%)
#   adding: cropped/IMG-202.png (stored 0%)
#   adding: cropped/IMG-1077.png (stored 0%)
#   adding: cropped/IMG-704.png (stored 0%)
#   adding: cropped/IMG-944.png (stored 0%)
#   adding: cropped/IMG-1030.png (stored 0%)
#   adding: cropped/IMG-83.png (stored 0%)
#   adding: cropped/IMG-1140.png (stored 0%)
#   adding: cropped/IMG-93.png (stored 0%)
#   adding: cropped/IMG-1050.png (stored 0%)
#   adding: cropped/IMG-1691.png (stored 0%)
#   adding: cropped/IMG-1097.png (stored 0%)
#   adding: cropped/IMG-1270.png (stored 0%)
#   adding: cropped/IMG-119.png (stored 0%)
#   adding: cropped/IMG-1810.png (deflated 1%)
#   adding: cropped/IMG-159.png (stored 0%)
#   adding: cropped/IMG-97.png (stored 0%)
#   adding: cropped/IMG-1455.png (stored 0%)
#   adding: cropped/IMG-1147.png (stored 0%)
#   adding: cropped/IMG-235.png (stored 0%)
#   adding: cropped/IMG-283.png (stored 0%)
#   adding: cropped/IMG-1752.png (stored 0%)
#   adding: cropped/IMG-970.png (stored 0%)
#   adding: cropped/IMG-947.png (stored 0%)
#   adding: cropped/IMG-693.png (stored 0%)
#   adding: cropped/IMG-1084.png (stored 0%)
#   adding: cropped/IMG-1718.png (stored 0%)
#   adding: cropped/IMG-575.png (stored 0%)
#   adding: cropped/IMG-1423.png (stored 0%)
#   adding: cropped/IMG-1087.png (stored 0%)
#   adding: cropped/IMG-1481.png (stored 0%)
#   adding: cropped/IMG-905.png (stored 0%)
#   adding: cropped/IMG-1330.png (stored 0%)
#   adding: cropped/IMG-919.png (stored 0%)
#   adding: cropped/IMG-581.png (stored 0%)
#   adding: cropped/IMG-1079.png (stored 0%)
#   adding: cropped/IMG-1059.png (stored 0%)
#   adding: cropped/IMG-534.png (stored 0%)
#   adding: cropped/IMG-1782.png (deflated 1%)
#   adding: cropped/IMG-1792.png (stored 0%)
#   adding: cropped/IMG-1152.png (stored 0%)
#   adding: cropped/IMG-913.png (stored 0%)
#   adding: cropped/IMG-300.png (stored 0%)
#   adding: cropped/IMG-1471.png (stored 0%)
#   adding: cropped/IMG-365.png (stored 0%)
#   adding: cropped/IMG-1532.png (stored 0%)
#   adding: cropped/IMG-392.png (stored 0%)
#   adding: cropped/IMG-655.png (stored 0%)
#   adding: cropped/IMG-18.png (stored 0%)
#   adding: cropped/IMG-336.png (stored 0%)
#   adding: cropped/IMG-1670.png (stored 0%)
#   adding: cropped/IMG-1442.png (stored 0%)
#   adding: cropped/IMG-279.png (stored 0%)
#   adding: cropped/IMG-1634.png (stored 0%)
#   adding: cropped/IMG-835.png (stored 0%)
#   adding: cropped/IMG-1600.png (stored 0%)
#   adding: cropped/IMG-1535.png (stored 0%)
#   adding: cropped/IMG-38.png (stored 0%)
#   adding: cropped/IMG-1720.png (stored 0%)
#   adding: cropped/IMG-1071.png (stored 0%)
#   adding: cropped/IMG-1667.png (stored 0%)
#   adding: cropped/IMG-1144.png (stored 0%)
#   adding: cropped/IMG-47.png (stored 0%)
#   adding: cropped/IMG-809.png (stored 0%)
#   adding: cropped/IMG-824.png (stored 0%)
#   adding: cropped/IMG-578.png (stored 0%)
#   adding: cropped/IMG-254.png (stored 0%)
#   adding: cropped/IMG-167.png (stored 0%)
#   adding: cropped/IMG-332.png (stored 0%)
#   adding: cropped/IMG-1068.png (stored 0%)
#   adding: cropped/IMG-711.png (stored 0%)
#   adding: cropped/IMG-102.png (stored 0%)
#   adding: cropped/IMG-1613.png (stored 0%)
#   adding: cropped/IMG-1426.png (stored 0%)
#   adding: cropped/IMG-554.png (stored 0%)
#   adding: cropped/IMG-843.png (stored 0%)
#   adding: cropped/IMG-1452.png (stored 0%)
#   adding: cropped/IMG-539.png (stored 0%)
#   adding: cropped/IMG-669.png (stored 0%)
#   adding: cropped/IMG-237.png (stored 0%)
#   adding: cropped/IMG-1726.png (stored 0%)
#   adding: cropped/IMG-1439.png (stored 0%)
#   adding: cropped/IMG-1597.png (stored 0%)
#   adding: cropped/IMG-547.png (stored 0%)
#   adding: cropped/IMG-1044.png (stored 0%)
#   adding: cropped/IMG-1676.png (stored 0%)
#   adding: cropped/IMG-41.png (stored 0%)
#   adding: cropped/IMG-325.png (stored 0%)
#   adding: cropped/IMG-1337.png (stored 0%)
#   adding: cropped/IMG-207.png (stored 0%)
#   adding: cropped/IMG-1018.png (stored 0%)
#   adding: cropped/IMG-1551.png (stored 0%)
#   adding: cropped/IMG-122.png (stored 0%)
#   adding: cropped/IMG-1352.png (stored 0%)
#   adding: cropped/IMG-452.png (stored 0%)
#   adding: cropped/IMG-675.png (stored 0%)
#   adding: cropped/IMG-417.png (stored 0%)
#   adding: cropped/IMG-1051.png (stored 0%)
#   adding: cropped/IMG-588.png (stored 0%)
#   adding: cropped/IMG-1070.png (stored 0%)
#   adding: cropped/IMG-1219.png (stored 0%)
#   adding: cropped/IMG-954.png (stored 0%)
#   adding: cropped/IMG-653.png (stored 0%)
#   adding: cropped/IMG-476.png (stored 0%)
#   adding: cropped/IMG-1482.png (stored 0%)
#   adding: cropped/IMG-599.png (stored 0%)
#   adding: cropped/IMG-1645.png (stored 0%)
#   adding: cropped/IMG-320.png (stored 0%)
#   adding: cropped/IMG-1766.png (stored 0%)
#   adding: cropped/IMG-638.png (stored 0%)
#   adding: cropped/IMG-998.png (stored 0%)
#   adding: cropped/IMG-830.png (stored 0%)
#   adding: cropped/IMG-1328.png (stored 0%)
#   adding: cropped/IMG-810.png (stored 0%)
#   adding: cropped/IMG-175.png (stored 0%)
#   adding: cropped/IMG-152.png (stored 0%)
#   adding: cropped/IMG-1467.png (stored 0%)
#   adding: cropped/IMG-281.png (stored 0%)
#   adding: cropped/IMG-1566.png (stored 0%)
#   adding: cropped/IMG-126.png (stored 0%)
#   adding: cropped/IMG-1135.png (stored 0%)
#   adding: cropped/IMG-189.png (stored 0%)
#   adding: cropped/IMG-198.png (stored 0%)
#   adding: cropped/IMG-172.png (stored 0%)
#   adding: cropped/IMG-1228.png (stored 0%)
#   adding: cropped/IMG-747.png (stored 0%)
#   adding: cropped/IMG-1677.png (stored 0%)
#   adding: cropped/IMG-968.png (stored 0%)
#   adding: cropped/IMG-187.png (stored 0%)
#   adding: cropped/IMG-645.png (stored 0%)
#   adding: cropped/IMG-715.png (stored 0%)
#   adding: cropped/IMG-883.png (stored 0%)
#   adding: cropped/IMG-838.png (stored 0%)
#   adding: cropped/IMG-115.png (stored 0%)
#   adding: cropped/IMG-952.png (stored 0%)
#   adding: cropped/IMG-267.png (stored 0%)
#   adding: cropped/IMG-1341.png (stored 0%)
#   adding: cropped/IMG-31.png (stored 0%)
#   adding: cropped/IMG-1637.png (stored 0%)
#   adding: cropped/IMG-468.png (stored 0%)
#   adding: cropped/IMG-1015.png (stored 0%)
#   adding: cropped/IMG-1794.png (deflated 6%)
#   adding: cropped/IMG-1100.png (stored 0%)
#   adding: cropped/IMG-1386.png (stored 0%)
#   adding: cropped/IMG-1358.png (stored 0%)
#   adding: cropped/IMG-1319.png (stored 0%)
#   adding: cropped/IMG-1615.png (stored 0%)
#   adding: cropped/IMG-1249.png (stored 0%)
#   adding: cropped/IMG-20.png (stored 0%)
#   adding: cropped/IMG-1446.png (stored 0%)
#   adding: cropped/IMG-1240.png (stored 0%)
#   adding: cropped/IMG-91.png (stored 0%)
#   adding: cropped/IMG-1259.png (stored 0%)
#   adding: cropped/IMG-1379.png (stored 0%)
#   adding: cropped/IMG-1394.png (stored 0%)
#   adding: cropped/IMG-1143.png (stored 0%)
#   adding: cropped/IMG-107.png (stored 0%)
#   adding: cropped/IMG-1246.png (stored 0%)
#   adding: cropped/IMG-1703.png (stored 0%)
#   adding: cropped/IMG-1236.png (stored 0%)
#   adding: cropped/IMG-1715.png (stored 0%)
#   adding: cropped/IMG-1702.png (stored 0%)
#   adding: cropped/IMG-475.png (stored 0%)
#   adding: cropped/IMG-1137.png (stored 0%)
#   adding: cropped/IMG-1381.png (stored 0%)
#   adding: cropped/IMG-140.png (stored 0%)
#   adding: cropped/IMG-360.png (stored 0%)
#   adding: cropped/IMG-1470.png (stored 0%)
#   adding: cropped/IMG-620.png (stored 0%)
#   adding: cropped/IMG-1590.png (stored 0%)
#   adding: cropped/IMG-1300.png (stored 0%)
#   adding: cropped/IMG-297.png (stored 0%)
#   adding: cropped/IMG-873.png (stored 0%)
#   adding: cropped/IMG-1433.png (stored 0%)
#   adding: cropped/IMG-1357.png (stored 0%)
#   adding: cropped/IMG-967.png (stored 0%)
#   adding: cropped/IMG-1522.png (stored 0%)
#   adding: cropped/IMG-1350.png (stored 0%)
#   adding: cropped/IMG-125.png (stored 0%)
#   adding: cropped/IMG-791.png (stored 0%)
#   adding: cropped/IMG-531.png (stored 0%)
#   adding: cropped/IMG-981.png (stored 0%)
#   adding: cropped/IMG-1641.png (stored 0%)
#   adding: cropped/IMG-1028.png (stored 0%)
#   adding: cropped/IMG-385.png (stored 0%)
#   adding: cropped/IMG-1662.png (stored 0%)
#   adding: cropped/IMG-312.png (stored 0%)
#   adding: cropped/IMG-1543.png (stored 0%)
#   adding: cropped/IMG-415.png (stored 0%)
#   adding: cropped/IMG-1343.png (stored 0%)
#   adding: cropped/IMG-950.png (stored 0%)
#   adding: cropped/IMG-975.png (stored 0%)
#   adding: cropped/IMG-12.png (stored 0%)
#   adding: cropped/IMG-388.png (stored 0%)
#   adding: cropped/IMG-1542.png (stored 0%)
#   adding: cropped/IMG-1631.png (stored 0%)
#   adding: cropped/IMG-1001.png (stored 0%)
#   adding: cropped/IMG-1274.png (stored 0%)
#   adding: cropped/IMG-1709.png (stored 0%)
#   adding: cropped/IMG-510.png (stored 0%)
#   adding: cropped/IMG-256.png (stored 0%)
#   adding: cropped/IMG-480.png (stored 0%)
#   adding: cropped/IMG-1104.png (stored 0%)
#   adding: cropped/IMG-608.png (stored 0%)
#   adding: cropped/IMG-1175.png (stored 0%)
#   adding: cropped/IMG-1682.png (stored 0%)
#   adding: cropped/IMG-730.png (stored 0%)
#   adding: cropped/IMG-1490.png (stored 0%)
#   adding: cropped/IMG-1684.png (stored 0%)
#   adding: cropped/IMG-190.png (stored 0%)
#   adding: cropped/IMG-308.png (stored 0%)
#   adding: cropped/IMG-1276.png (stored 0%)
#   adding: cropped/IMG-1304.png (stored 0%)
#   adding: cropped/IMG-628.png (stored 0%)
#   adding: cropped/IMG-847.png (stored 0%)
#   adding: cropped/IMG-869.png (stored 0%)
#   adding: cropped/IMG-416.png (stored 0%)
#   adding: cropped/IMG-314.png (stored 0%)
#   adding: cropped/IMG-894.png (stored 0%)
#   adding: cropped/IMG-1699.png (stored 0%)
#   adding: cropped/IMG-803.png (stored 0%)
#   adding: cropped/IMG-72.png (stored 0%)
#   adding: cropped/IMG-44.png (stored 0%)
#   adding: cropped/IMG-36.png (stored 0%)
#   adding: cropped/IMG-1580.png (stored 0%)
#   adding: cropped/IMG-1587.png (stored 0%)
#   adding: cropped/IMG-1746.png (stored 0%)
#   adding: cropped/IMG-820.png (stored 0%)
#   adding: cropped/IMG-931.png (stored 0%)
#   adding: cropped/IMG-1486.png (stored 0%)
#   adding: cropped/IMG-983.png (stored 0%)
#   adding: cropped/IMG-694.png (stored 0%)
#   adding: cropped/IMG-775.png (stored 0%)
#   adding: cropped/IMG-1541.png (stored 0%)
#   adding: cropped/IMG-855.png (stored 0%)
#   adding: cropped/IMG-856.png (stored 0%)
#   adding: cropped/IMG-1227.png (stored 0%)
#   adding: cropped/IMG-278.png (stored 0%)
#   adding: cropped/IMG-1704.png (stored 0%)
#   adding: cropped/IMG-800.png (stored 0%)
#   adding: cropped/IMG-143.png (stored 0%)
#   adding: cropped/IMG-275.png (stored 0%)
#   adding: cropped/IMG-895.png (stored 0%)
#   adding: cropped/IMG-786.png (stored 0%)
#   adding: cropped/IMG-1114.png (stored 0%)
#   adding: cropped/IMG-740.png (stored 0%)
#   adding: cropped/IMG-1.png (stored 0%)
#   adding: cropped/IMG-999.png (stored 0%)
#   adding: cropped/IMG-134.png (stored 0%)
#   adding: cropped/IMG-502.png (stored 0%)
#   adding: cropped/IMG-533.png (stored 0%)
#   adding: cropped/IMG-1094.png (stored 0%)
#   adding: cropped/IMG-671.png (stored 0%)
#   adding: cropped/IMG-1231.png (stored 0%)
#   adding: cropped/IMG-685.png (stored 0%)
#   adding: cropped/IMG-240.png (stored 0%)
#   adding: cropped/IMG-1675.png (stored 0%)
#   adding: cropped/IMG-1630.png (stored 0%)
#   adding: cropped/IMG-801.png (stored 0%)
#   adding: cropped/IMG-423.png (stored 0%)
#   adding: cropped/IMG-1514.png (stored 0%)
#   adding: cropped/IMG-553.png (stored 0%)
#   adding: cropped/IMG-218.png (stored 0%)
#   adding: cropped/IMG-776.png (stored 0%)
#   adding: cropped/IMG-274.png (stored 0%)
#   adding: cropped/IMG-150.png (stored 0%)
#   adding: cropped/IMG-1335.png (stored 0%)
#   adding: cropped/IMG-1700.png (stored 0%)
#   adding: cropped/IMG-58.png (stored 0%)
#   adding: cropped/IMG-19.png (stored 0%)
#   adding: cropped/IMG-84.png (stored 0%)
#   adding: cropped/IMG-1000.png (stored 0%)
#   adding: cropped/IMG-1705.png (stored 0%)
#   adding: cropped/IMG-1505.png (stored 0%)
#   adding: cropped/IMG-101.png (stored 0%)
#   adding: cropped/IMG-739.png (stored 0%)
#   adding: cropped/IMG-316.png (stored 0%)
#   adding: cropped/IMG-872.png (stored 0%)
#   adding: cropped/IMG-1348.png (stored 0%)
#   adding: cropped/IMG-1797.png (deflated 1%)
#   adding: cropped/IMG-911.png (stored 0%)
#   adding: cropped/IMG-1430.png (stored 0%)
#   adding: cropped/IMG-945.png (stored 0%)
#   adding: cropped/IMG-1061.png (stored 0%)
#   adding: cropped/IMG-1707.png (stored 0%)
#   adding: cropped/IMG-1313.png (stored 0%)
#   adding: cropped/IMG-878.png (stored 0%)
#   adding: cropped/IMG-1552.png (stored 0%)
#   adding: cropped/IMG-9.png (stored 0%)
#   adding: cropped/IMG-545.png (stored 0%)
#   adding: cropped/IMG-25.png (stored 0%)
#   adding: cropped/IMG-1487.png (stored 0%)
#   adding: cropped/IMG-1564.png (stored 0%)
#   adding: cropped/IMG-223.png (stored 0%)
#   adding: cropped/IMG-1424.png (stored 0%)
#   adding: cropped/IMG-1650.png (stored 0%)
#   adding: cropped/IMG-435.png (stored 0%)
#   adding: cropped/IMG-160.png (stored 0%)
#   adding: cropped/IMG-509.png (stored 0%)
#   adding: cropped/IMG-1740.png (stored 0%)
#   adding: cropped/IMG-239.png (stored 0%)
#   adding: cropped/IMG-298.png (stored 0%)
#   adding: cropped/IMG-67.png (stored 0%)
#   adding: cropped/IMG-479.png (stored 0%)
#   adding: cropped/IMG-529.png (stored 0%)
#   adding: cropped/IMG-393.png (stored 0%)
#   adding: cropped/IMG-923.png (stored 0%)
#   adding: cropped/IMG-1029.png (stored 0%)
#   adding: cropped/IMG-103.png (stored 0%)
#   adding: cropped/IMG-293.png (stored 0%)
#   adding: cropped/IMG-1171.png (stored 0%)
#   adding: cropped/IMG-147.png (stored 0%)
#   adding: cropped/IMG-1507.png (stored 0%)
#   adding: cropped/IMG-1314.png (stored 0%)
#   adding: cropped/IMG-1108.png (stored 0%)
#   adding: cropped/IMG-1367.png (stored 0%)
#   adding: cropped/IMG-1655.png (stored 0%)
#   adding: cropped/IMG-432.png (stored 0%)
#   adding: cropped/IMG-1562.png (stored 0%)
#   adding: cropped/IMG-377.png (stored 0%)
#   adding: cropped/IMG-1714.png (stored 0%)
#   adding: cropped/IMG-111.png (stored 0%)
#   adding: cropped/IMG-1576.png (stored 0%)
#   adding: cropped/IMG-1166.png (stored 0%)
#   adding: cropped/IMG-1732.png (stored 0%)
#   adding: cropped/IMG-916.png (stored 0%)
#   adding: cropped/IMG-519.png (stored 0%)
#   adding: cropped/IMG-1391.png (stored 0%)
#   adding: cropped/IMG-444.png (stored 0%)
#   adding: cropped/IMG-525.png (stored 0%)
#   adding: cropped/IMG-1728.png (stored 0%)
#   adding: cropped/IMG-331.png (stored 0%)
#   adding: cropped/IMG-53.png (stored 0%)
#   adding: cropped/IMG-384.png (stored 0%)
#   adding: cropped/IMG-1824.png (stored 0%)
#   adding: cropped/IMG-1529.png (stored 0%)
#   adding: cropped/IMG-39.png (stored 0%)
#   adding: cropped/IMG-376.png (stored 0%)
#   adding: cropped/IMG-622.png (stored 0%)
#   adding: cropped/IMG-1640.png (stored 0%)
#   adding: cropped/IMG-1183.png (stored 0%)
#   adding: cropped/IMG-287.png (stored 0%)
#   adding: cropped/IMG-496.png (stored 0%)
#   adding: cropped/IMG-650.png (stored 0%)
#   adding: cropped/IMG-564.png (stored 0%)
#   adding: cropped/IMG-1359.png (stored 0%)
#   adding: cropped/IMG-292.png (stored 0%)
#   adding: cropped/IMG-1355.png (stored 0%)
#   adding: cropped/IMG-380.png (stored 0%)
#   adding: cropped/IMG-474.png (stored 0%)
#   adding: cropped/IMG-1435.png (stored 0%)
#   adding: cropped/IMG-61.png (stored 0%)
#   adding: cropped/IMG-501.png (stored 0%)
#   adding: cropped/IMG-1791.png (stored 0%)
#   adding: cropped/IMG-698.png (stored 0%)
#   adding: cropped/IMG-1565.png (stored 0%)
#   adding: cropped/IMG-334.png (stored 0%)
#   adding: cropped/IMG-419.png (stored 0%)
#   adding: cropped/IMG-1765.png (stored 0%)
#   adding: cropped/IMG-174.png (stored 0%)
#   adding: cropped/IMG-1112.png (stored 0%)
#   adding: cropped/IMG-850.png (stored 0%)
#   adding: cropped/IMG-179.png (stored 0%)
#   adding: cropped/IMG-1627.png (stored 0%)
#   adding: cropped/IMG-1316.png (stored 0%)
#   adding: cropped/IMG-1287.png (stored 0%)
#   adding: cropped/IMG-1081.png (stored 0%)
#   adding: cropped/IMG-817.png (stored 0%)
#   adding: cropped/IMG-358.png (stored 0%)
#   adding: cropped/IMG-1414.png (stored 0%)
#   adding: cropped/IMG-1591.png (stored 0%)
#   adding: cropped/IMG-181.png (stored 0%)
#   adding: cropped/IMG-598.png (stored 0%)
#   adding: cropped/IMG-1176.png (stored 0%)
#   adding: cropped/IMG-798.png (stored 0%)
#   adding: cropped/IMG-702.png (stored 0%)
#   adding: cropped/IMG-1547.png (stored 0%)
#   adding: cropped/IMG-592.png (stored 0%)
#   adding: cropped/IMG-557.png (stored 0%)
#   adding: cropped/IMG-449.png (stored 0%)
#   adding: cropped/IMG-949.png (stored 0%)
#   adding: cropped/IMG-1160.png (stored 0%)
#   adding: cropped/IMG-665.png (stored 0%)
#   adding: cropped/IMG-1106.png (stored 0%)
#   adding: cropped/IMG-1064.png (stored 0%)
#   adding: cropped/IMG-158.png (stored 0%)
#   adding: cropped/IMG-329.png (stored 0%)
#   adding: cropped/IMG-646.png (stored 0%)
#   adding: cropped/IMG-1516.png (stored 0%)
#   adding: cropped/IMG-1444.png (stored 0%)
#   adding: cropped/IMG-173.png (stored 0%)
#   adding: cropped/IMG-1002.png (stored 0%)
#   adding: cropped/IMG-1731.png (stored 0%)
#   adding: cropped/IMG-481.png (stored 0%)
#   adding: cropped/IMG-459.png (stored 0%)
#   adding: cropped/IMG-712.png (stored 0%)
#   adding: cropped/IMG-1150.png (stored 0%)
#   adding: cropped/IMG-558.png (stored 0%)
#   adding: cropped/IMG-1515.png (stored 0%)
#   adding: cropped/IMG-1008.png (stored 0%)
#   adding: cropped/IMG-1808.png (stored 0%)
#   adding: cropped/IMG-10.png (stored 0%)
#   adding: cropped/IMG-1695.png (stored 0%)
#   adding: cropped/IMG-656.png (stored 0%)
#   adding: cropped/IMG-901.png (stored 0%)
#   adding: cropped/IMG-153.png (stored 0%)
#   adding: cropped/IMG-1508.png (stored 0%)
#   adding: cropped/IMG-743.png (stored 0%)
#   adding: cropped/IMG-313.png (stored 0%)
#   adding: cropped/IMG-1483.png (stored 0%)
#   adding: cropped/IMG-1793.png (stored 0%)
#   adding: cropped/IMG-280.png (stored 0%)
#   adding: cropped/IMG-921.png (stored 0%)
#   adding: cropped/IMG-347.png (stored 0%)
#   adding: cropped/IMG-193.png (stored 0%)
#   adding: cropped/IMG-1153.png (stored 0%)
#   adding: cropped/IMG-1354.png (stored 0%)
#   adding: cropped/IMG-1035.png (stored 0%)
#   adding: cropped/IMG-1046.png (stored 0%)
#   adding: cropped/IMG-1585.png (stored 0%)
#   adding: cropped/IMG-1774.png (deflated 1%)
#   adding: cropped/IMG-1606.png (stored 0%)
#   adding: cropped/IMG-1561.png (stored 0%)
#   adding: cropped/IMG-436.png (stored 0%)
#   adding: cropped/IMG-899.png (stored 0%)
#   adding: cropped/IMG-607.png (stored 0%)
#   adding: cropped/IMG-600.png (stored 0%)
#   adding: cropped/IMG-1226.png (stored 0%)
#   adding: cropped/IMG-782.png (stored 0%)
#   adding: cropped/IMG-1484.png (stored 0%)
#   adding: cropped/IMG-979.png (stored 0%)
#   adding: cropped/IMG-753.png (stored 0%)
#   adding: cropped/IMG-149.png (stored 0%)
#   adding: cropped/IMG-299.png (stored 0%)
#   adding: cropped/IMG-1521.png (stored 0%)
#   adding: cropped/IMG-1418.png (stored 0%)
#   adding: cropped/IMG-117.png (stored 0%)
#   adding: cropped/IMG-262.png (stored 0%)
#   adding: cropped/IMG-1525.png (stored 0%)
#   adding: cropped/IMG-973.png (stored 0%)
#   adding: cropped/IMG-528.png (stored 0%)
#   adding: cropped/IMG-527.png (stored 0%)
#   adding: cropped/IMG-865.png (stored 0%)
#   adding: cropped/IMG-1448.png (stored 0%)
#   adding: cropped/IMG-255.png (stored 0%)
#   adding: cropped/IMG-619.png (stored 0%)
#   adding: cropped/IMG-601.png (stored 0%)
#   adding: cropped/IMG-1625.png (stored 0%)
#   adding: cropped/IMG-1399.png (stored 0%)
#   adding: cropped/IMG-870.png (stored 0%)
#   adding: cropped/IMG-1208.png (stored 0%)
#   adding: cropped/IMG-1723.png (stored 0%)
#   adding: cropped/IMG-1408.png (stored 0%)
#   adding: cropped/IMG-1571.png (stored 0%)
#   adding: cropped/IMG-1761.png (stored 0%)
#   adding: cropped/IMG-401.png (stored 0%)
#   adding: cropped/IMG-112.png (stored 0%)
#   adding: cropped/IMG-593.png (stored 0%)
#   adding: cropped/IMG-212.png (stored 0%)
#   adding: cropped/IMG-821.png (stored 0%)
#   adding: cropped/IMG-1523.png (stored 0%)
#   adding: cropped/IMG-413.png (stored 0%)
#   adding: cropped/IMG-875.png (stored 0%)
#   adding: cropped/IMG-428.png (stored 0%)
#   adding: cropped/IMG-438.png (stored 0%)
#   adding: cropped/IMG-831.png (stored 0%)
#   adding: cropped/IMG-1644.png (stored 0%)
#   adding: cropped/IMG-1078.png (stored 0%)
#   adding: cropped/IMG-45.png (stored 0%)
#   adding: cropped/IMG-1178.png (stored 0%)
#   adding: cropped/IMG-1787.png (stored 0%)
#   adding: cropped/IMG-1602.png (stored 0%)
#   adding: cropped/IMG-372.png (stored 0%)
#   adding: cropped/IMG-641.png (stored 0%)
#   adding: cropped/IMG-507.png (stored 0%)
#   adding: cropped/IMG-364.png (stored 0%)
#   adding: cropped/IMG-594.png (stored 0%)
#   adding: cropped/IMG-225.png (stored 0%)
#   adding: cropped/IMG-1492.png (stored 0%)
#   adding: cropped/IMG-324.png (stored 0%)
#   adding: cropped/IMG-447.png (stored 0%)
#   adding: cropped/IMG-411.png (stored 0%)
#   adding: cropped/IMG-1556.png (stored 0%)
#   adding: cropped/IMG-1725.png (stored 0%)
#   adding: cropped/IMG-663.png (stored 0%)
#   adding: cropped/IMG-1573.png (stored 0%)
#   adding: cropped/IMG-609.png (stored 0%)
#   adding: cropped/IMG-185.png (stored 0%)
#   adding: cropped/IMG-815.png (stored 0%)
#   adding: cropped/IMG-1020.png (stored 0%)
#   adding: cropped/IMG-1754.png (stored 0%)
#   adding: cropped/IMG-426.png (stored 0%)
#   adding: cropped/IMG-1256.png (stored 0%)
#   adding: cropped/IMG-1195.png (stored 0%)
#   adding: cropped/IMG-991.png (stored 0%)
#   adding: cropped/IMG-40.png (stored 0%)
#   adding: cropped/IMG-1749.png (stored 0%)
#   adding: cropped/IMG-244.png (stored 0%)
#   adding: cropped/IMG-1062.png (stored 0%)
#   adding: cropped/IMG-1039.png (stored 0%)
#   adding: cropped/IMG-978.png (stored 0%)
#   adding: cropped/IMG-904.png (stored 0%)
#   adding: cropped/IMG-724.png (stored 0%)
#   adding: cropped/IMG-1023.png (stored 0%)
#   adding: cropped/IMG-826.png (stored 0%)
#   adding: cropped/IMG-990.png (stored 0%)
#   adding: cropped/IMG-642.png (stored 0%)
#   adding: cropped/IMG-1033.png (stored 0%)
#   adding: cropped/IMG-7.png (stored 0%)
#   adding: cropped/IMG-857.png (stored 0%)
#   adding: cropped/IMG-1306.png (stored 0%)
#   adding: cropped/IMG-1269.png (stored 0%)
#   adding: cropped/IMG-734.png (stored 0%)
#   adding: cropped/IMG-1472.png (stored 0%)
#   adding: cropped/IMG-1604.png (stored 0%)
#   adding: cropped/IMG-1609.png (stored 0%)
#   adding: cropped/IMG-1491.png (stored 0%)
#   adding: cropped/IMG-431.png (stored 0%)
#   adding: cropped/IMG-408.png (stored 0%)
#   adding: cropped/IMG-1495.png (stored 0%)
#   adding: cropped/IMG-682.png (stored 0%)
#   adding: cropped/IMG-1285.png (stored 0%)
#   adding: cropped/IMG-846.png (stored 0%)
#   adding: cropped/IMG-943.png (stored 0%)
#   adding: cropped/IMG-953.png (stored 0%)
#   adding: cropped/IMG-450.png (stored 0%)
#   adding: cropped/IMG-1098.png (stored 0%)
#   adding: cropped/IMG-583.png (stored 0%)
#   adding: cropped/IMG-1063.png (stored 0%)
#   adding: cropped/IMG-1292.png (stored 0%)
#   adding: cropped/IMG-1589.png (stored 0%)
#   adding: cropped/IMG-453.png (stored 0%)
#   adding: cropped/IMG-517.png (stored 0%)
#   adding: cropped/IMG-485.png (stored 0%)
#   adding: cropped/IMG-1172.png (stored 0%)
#   adding: cropped/IMG-288.png (stored 0%)
#   adding: cropped/IMG-306.png (stored 0%)
#   adding: cropped/IMG-455.png (stored 0%)
#   adding: cropped/IMG-1252.png (stored 0%)
#   adding: cropped/IMG-719.png (stored 0%)
#   adding: cropped/IMG-1297.png (stored 0%)
#   adding: cropped/IMG-1605.png (stored 0%)
#   adding: cropped/IMG-478.png (stored 0%)
#   adding: cropped/IMG-1790.png (stored 0%)
#   adding: cropped/IMG-440.png (stored 0%)
#   adding: cropped/IMG-171.png (stored 0%)
#   adding: cropped/IMG-1207.png (stored 0%)
#   adding: cropped/IMG-591.png (stored 0%)
#   adding: cropped/IMG-250.png (stored 0%)
#   adding: cropped/IMG-410.png (stored 0%)
#   adding: cropped/IMG-1668.png (stored 0%)
#   adding: cropped/IMG-245.png (stored 0%)
#   adding: cropped/IMG-430.png (stored 0%)
#   adding: cropped/IMG-454.png (stored 0%)
#   adding: cropped/IMG-108.png (stored 0%)
#   adding: cropped/IMG-226.png (stored 0%)
#   adding: cropped/IMG-977.png (stored 0%)
#   adding: cropped/IMG-242.png (stored 0%)
#   adding: cropped/IMG-1043.png (stored 0%)
#   adding: cropped/IMG-537.png (stored 0%)
#   adding: cropped/IMG-1090.png (stored 0%)
#   adding: cropped/IMG-1549.png (stored 0%)
#   adding: cropped/IMG-668.png (stored 0%)
#   adding: cropped/IMG-163.png (stored 0%)
#   adding: cropped/IMG-1779.png (stored 0%)
#   adding: cropped/IMG-197.png (stored 0%)
#   adding: cropped/IMG-335.png (stored 0%)
#   adding: cropped/IMG-929.png (stored 0%)
#   adding: cropped/IMG-1545.png (stored 0%)
#   adding: cropped/IMG-1237.png (stored 0%)
#   adding: cropped/IMG-1179.png (stored 0%)
#   adding: cropped/IMG-488.png (stored 0%)
#   adding: cropped/IMG-1216.png (stored 0%)
#   adding: cropped/IMG-572.png (stored 0%)
#   adding: cropped/IMG-1823.png (stored 0%)
#   adding: cropped/IMG-1624.png (stored 0%)
#   adding: cropped/IMG-1243.png (stored 0%)
#   adding: cropped/IMG-1318.png (stored 0%)
#   adding: cropped/IMG-405.png (stored 0%)
#   adding: cropped/IMG-1750.png (stored 0%)
#   adding: cropped/IMG-291.png (stored 0%)
#   adding: cropped/IMG-56.png (stored 0%)
#   adding: cropped/IMG-208.png (stored 0%)
#   adding: cropped/IMG-997.png (stored 0%)
#   adding: cropped/IMG-647.png (stored 0%)
#   adding: cropped/IMG-1131.png (stored 0%)
#   adding: cropped/IMG-927.png (stored 0%)
#   adding: cropped/IMG-260.png (stored 0%)
#   adding: cropped/IMG-673.png (stored 0%)
#   adding: cropped/IMG-21.png (stored 0%)
#   adding: cropped/IMG-1745.png (stored 0%)
#   adding: cropped/IMG-1708.png (stored 0%)
#   adding: cropped/IMG-318.png (stored 0%)
#   adding: cropped/IMG-1478.png (stored 0%)
#   adding: cropped/IMG-884.png (stored 0%)
#   adding: cropped/IMG-381.png (stored 0%)
#   adding: cropped/IMG-618.png (stored 0%)
#   adding: cropped/IMG-406.png (stored 0%)
#   adding: cropped/IMG-771.png (stored 0%)
#   adding: cropped/IMG-938.png (stored 0%)
#   adding: cropped/IMG-680.png (stored 0%)
#   adding: cropped/IMG-1688.png (stored 0%)
#   adding: cropped/IMG-1149.png (stored 0%)
#   adding: cropped/IMG-1388.png (stored 0%)
#   adding: cropped/IMG-1812.png (stored 0%)
#   adding: cropped/IMG-114.png (stored 0%)
#   adding: cropped/IMG-1517.png (stored 0%)
#   adding: cropped/IMG-569.png (stored 0%)
#   adding: cropped/IMG-845.png (stored 0%)
#   adding: cropped/IMG-1409.png (stored 0%)
#   adding: cropped/IMG-494.png (stored 0%)
#   adding: cropped/IMG-908.png (stored 0%)
#   adding: cropped/IMG-1453.png (stored 0%)
#   adding: cropped/IMG-1393.png (stored 0%)
#   adding: cropped/IMG-523.png (stored 0%)
#   adding: cropped/IMG-577.png (stored 0%)
#   adding: cropped/IMG-462.png (stored 0%)
#   adding: cropped/IMG-657.png (stored 0%)
#   adding: cropped/IMG-1265.png (stored 0%)
#   adding: cropped/IMG-177.png (stored 0%)
#   adding: cropped/IMG-1611.png (stored 0%)
#   adding: cropped/IMG-164.png (stored 0%)
#   adding: cropped/IMG-1396.png (stored 0%)
#   adding: cropped/IMG-1711.png (stored 0%)
#   adding: cropped/IMG-1045.png (stored 0%)
#   adding: cropped/IMG-1307.png (stored 0%)
#   adding: cropped/IMG-1370.png (stored 0%)
#   adding: cropped/IMG-303.png (stored 0%)
#   adding: cropped/IMG-1371.png (stored 0%)
#   adding: cropped/IMG-1264.png (stored 0%)
#   adding: cropped/IMG-352.png (stored 0%)
#   adding: cropped/IMG-576.png (stored 0%)
#   adding: cropped/IMG-567.png (stored 0%)
#   adding: cropped/IMG-289.png (stored 0%)
#   adding: cropped/IMG-1340.png (stored 0%)
#   adding: cropped/IMG-513.png (stored 0%)
#   adding: cropped/IMG-371.png (stored 0%)
#   adding: cropped/IMG-1233.png (stored 0%)
#   adding: cropped/IMG-374.png (stored 0%)
#   adding: cropped/IMG-1369.png (stored 0%)
#   adding: cropped/IMG-1290.png (stored 0%)
#   adding: cropped/IMG-1469.png (stored 0%)
#   adding: cropped/IMG-818.png (stored 0%)
#   adding: cropped/IMG-263.png (stored 0%)
#   adding: cropped/IMG-785.png (stored 0%)
#   adding: cropped/IMG-790.png (stored 0%)
#   adding: cropped/IMG-1420.png (stored 0%)
#   adding: cropped/IMG-736.png (stored 0%)
#   adding: cropped/IMG-487.png (stored 0%)
#   adding: cropped/IMG-729.png (stored 0%)
#   adding: cropped/IMG-942.png (stored 0%)
#   adding: cropped/IMG-373.png (stored 0%)
#   adding: cropped/IMG-3.png (stored 0%)
#   adding: cropped/IMG-849.png (stored 0%)
#   adding: cropped/IMG-1005.png (stored 0%)
#   adding: cropped/IMG-74.png (stored 0%)
#   adding: cropped/IMG-1298.png (stored 0%)
#   adding: cropped/IMG-936.png (stored 0%)
#   adding: cropped/IMG-1588.png (stored 0%)
#   adding: cropped/IMG-1181.png (stored 0%)
#   adding: cropped/IMG-232.png (stored 0%)
#   adding: cropped/IMG-1608.png (stored 0%)
#   adding: cropped/IMG-1353.png (stored 0%)
#   adding: cropped/IMG-784.png (stored 0%)
#   adding: cropped/IMG-511.png (stored 0%)
#   adding: cropped/IMG-178.png (stored 0%)
#   adding: cropped/IMG-1336.png (stored 0%)
#   adding: cropped/IMG-165.png (stored 0%)
#   adding: cropped/IMG-1315.png (stored 0%)
#   adding: cropped/IMG-1376.png (stored 0%)
#   adding: cropped/IMG-1713.png (stored 0%)
#   adding: cropped/IMG-859.png (stored 0%)
#   adding: cropped/IMG-862.png (stored 0%)
#   adding: cropped/IMG-1799.png (stored 0%)
#   adding: cropped/IMG-246.png (stored 0%)
#   adding: cropped/IMG-1665.png (stored 0%)
#   adding: cropped/IMG-1432.png (stored 0%)
#   adding: cropped/IMG-660.png (stored 0%)
#   adding: cropped/IMG-136.png (stored 0%)
#   adding: cropped/IMG-282.png (stored 0%)
#   adding: cropped/IMG-1599.png (stored 0%)
#   adding: cropped/IMG-1458.png (stored 0%)
#   adding: cropped/IMG-1817.png (stored 0%)
#   adding: cropped/IMG-57.png (stored 0%)
#   adding: cropped/IMG-713.png (stored 0%)
#   adding: cropped/IMG-767.png (stored 0%)
#   adding: cropped/IMG-1632.png (stored 0%)
#   adding: cropped/IMG-82.png (stored 0%)
#   adding: cropped/IMG-582.png (stored 0%)
#   adding: cropped/IMG-1145.png (stored 0%)
#   adding: cropped/IMG-544.png (stored 0%)
#   adding: cropped/IMG-748.png (stored 0%)
#   adding: cropped/IMG-120.png (stored 0%)
#   adding: cropped/IMG-170.png (stored 0%)
#   adding: cropped/IMG-1329.png (stored 0%)
#   adding: cropped/IMG-268.png (stored 0%)
#   adding: cropped/IMG-512.png (stored 0%)
#   adding: cropped/IMG-323.png (stored 0%)
#   adding: cropped/IMG-565.png (stored 0%)
#   adding: cropped/IMG-1302.png (stored 0%)
#   adding: cropped/IMG-1260.png (stored 0%)
#   adding: cropped/IMG-779.png (stored 0%)
#   adding: cropped/IMG-219.png (stored 0%)
#   adding: cropped/IMG-922.png (stored 0%)
#   adding: cropped/IMG-1451.png (stored 0%)
#   adding: cropped/IMG-714.png (stored 0%)
#   adding: cropped/IMG-972.png (stored 0%)
#   adding: cropped/IMG-549.png (stored 0%)
#   adding: cropped/IMG-871.png (stored 0%)
#   adding: cropped/IMG-788.png (stored 0%)
#   adding: cropped/IMG-498.png (stored 0%)
#   adding: cropped/IMG-700.png (stored 0%)
#   adding: cropped/IMG-87.png (stored 0%)
#   adding: cropped/IMG-1459.png (stored 0%)
#   adding: cropped/IMG-1250.png (stored 0%)
#   adding: cropped/IMG-1554.png (stored 0%)
#   adding: cropped/IMG-934.png (stored 0%)
#   adding: cropped/IMG-1170.png (stored 0%)
#   adding: cropped/IMG-966.png (stored 0%)
#   adding: cropped/IMG-98.png (stored 0%)
#   adding: cropped/IMG-677.png (stored 0%)
#   adding: cropped/IMG-1638.png (stored 0%)
#   adding: cropped/IMG-823.png (stored 0%)
#   adding: cropped/IMG-980.png (stored 0%)
#   adding: cropped/IMG-1460.png (stored 0%)
#   adding: cropped/IMG-1198.png (stored 0%)
#   adding: cropped/IMG-333.png (stored 0%)
#   adding: cropped/IMG-987.png (stored 0%)
#   adding: cropped/IMG-735.png (stored 0%)
#   adding: cropped/IMG-1331.png (stored 0%)
#   adding: cropped/IMG-876.png (stored 0%)
#   adding: cropped/IMG-1669.png (stored 0%)
#   adding: cropped/IMG-611.png (stored 0%)
#   adding: cropped/IMG-1173.png (stored 0%)
#   adding: cropped/IMG-1281.png (stored 0%)
#   adding: cropped/IMG-1215.png (stored 0%)
#   adding: cropped/IMG-1447.png (stored 0%)
#   adding: cropped/IMG-1053.png (stored 0%)
#   adding: cropped/IMG-467.png (stored 0%)
#   adding: cropped/IMG-909.png (stored 0%)
#   adding: cropped/IMG-1759.png (stored 0%)
#   adding: cropped/IMG-69.png (stored 0%)
#   adding: cropped/IMG-745.png (stored 0%)
#   adding: cropped/IMG-760.png (stored 0%)
#   adding: cropped/IMG-769.png (stored 0%)
#   adding: cropped/IMG-1134.png (stored 0%)
#   adding: cropped/IMG-804.png (stored 0%)
#   adding: cropped/IMG-1781.png (stored 0%)
#   adding: cropped/IMG-23.png (stored 0%)
#   adding: cropped/IMG-1474.png (stored 0%)
#   adding: cropped/IMG-1238.png (stored 0%)
#   adding: cropped/IMG-1159.png (stored 0%)
#   adding: cropped/IMG-105.png (stored 0%)
#   adding: cropped/IMG-302.png (stored 0%)
#   adding: cropped/IMG-984.png (stored 0%)
#   adding: cropped/IMG-1701.png (stored 0%)
#   adding: cropped/IMG-1400.png (stored 0%)
#   adding: cropped/IMG-885.png (stored 0%)
#   adding: cropped/IMG-816.png (stored 0%)
#   adding: cropped/IMG-1299.png (stored 0%)
#   adding: cropped/IMG-679.png (stored 0%)
# ...
#   adding: cropped/IMG-49.png (stored 0%)
#   adding: cropped/IMG-759.png (stored 0%)
#   adding: cropped/IMG-366.png (stored 0%)
#   adding: cropped/IMG-273.png (stored 0%)
#   adding: cropped/IMG-530.png (stored 0%)
#   adding: cropped/IMG-1592.png (stored 0%)
#   adding: cropped/IMG-1747.png (stored 0%)
#   adding: cropped/IMG-182.png (stored 0%)
#   adding: cropped/IMG-35.png (stored 0%)
#   adding: cropped/IMG-1457.png (stored 0%)
#   adding: cropped/IMG-941.png (stored 0%)
#   adding: cropped/IMG-1363.png (stored 0%)
#   adding: cropped/IMG-1783.png (deflated 1%)
#   adding: cropped/IMG-1672.png (stored 0%)
#   adding: cropped/IMG-1267.png (stored 0%)
#   adding: cropped/IMG-156.png (stored 0%)
#   adding: cropped/IMG-1784.png (stored 0%)
#   adding: cropped/IMG-59.png (stored 0%)
#   adding: cropped/IMG-418.png (stored 0%)
#   adding: cropped/IMG-1563.png (stored 0%)
#   adding: cropped/IMG-1546.png (stored 0%)
#   adding: cropped/IMG-1526.png (stored 0%)
#   adding: cropped/IMG-1539.png (stored 0%)
#   adding: cropped/IMG-1443.png (stored 0%)
#   adding: cropped/IMG-948.png (stored 0%)
#   adding: cropped/IMG-1091.png (stored 0%)
#   adding: cropped/IMG-1230.png (stored 0%)
#   adding: cropped/IMG-230.png (stored 0%)
#   adding: cropped/IMG-1805.png (deflated 2%)
#   adding: cropped/IMG-342.png (stored 0%)
#   adding: cropped/IMG-63.png (stored 0%)
#   adding: cropped/IMG-169.png (stored 0%)
#   adding: cropped/IMG-463.png (stored 0%)
#   adding: cropped/IMG-974.png (stored 0%)
#   adding: cropped/IMG-503.png (stored 0%)
#   adding: cropped/IMG-1222.png (stored 0%)
#   adding: cropped/IMG-1680.png (stored 0%)
#   adding: cropped/IMG-1445.png (stored 0%)
#   adding: cropped/IMG-1010.png (stored 0%)
#   adding: cropped/IMG-1698.png (stored 0%)
#   adding: cropped/IMG-1188.png (stored 0%)
#   adding: cropped/IMG-524.png (stored 0%)
#   adding: cropped/IMG-589.png (stored 0%)
#   adding: cropped/IMG-104.png (stored 0%)
#   adding: cropped/IMG-286.png (stored 0%)
#   adding: cropped/IMG-460.png (stored 0%)
#   adding: cropped/IMG-231.png (stored 0%)
#   adding: cropped/IMG-1295.png (stored 0%)
#   adding: cropped/IMG-301.png (stored 0%)
#   adding: cropped/IMG-368.png (stored 0%)
#   adding: cropped/IMG-1234.png (stored 0%)
#   adding: cropped/IMG-1601.png (stored 0%)
#   adding: cropped/IMG-15.png (stored 0%)
#   adding: cropped/IMG-1165.png (stored 0%)
#   adding: cropped/IMG-1557.png (stored 0%)
#   adding: cropped/IMG-5.png (stored 0%)
#   adding: cropped/IMG-1193.png (stored 0%)
#   adding: cropped/IMG-1368.png (stored 0%)
#   adding: cropped/IMG-133.png (stored 0%)
#   adding: cropped/IMG-568.png (stored 0%)
#   adding: cropped/IMG-640.png (stored 0%)
#   adding: cropped/IMG-404.png (stored 0%)
#   adding: cropped/IMG-109.png (stored 0%)
#   adding: cropped/IMG-195.png (stored 0%)
#   adding: cropped/IMG-1770.png (deflated 2%)
#   adding: cropped/IMG-1275.png (stored 0%)
#   adding: cropped/IMG-732.png (stored 0%)
#   adding: cropped/IMG-763.png (stored 0%)
#   adding: cropped/IMG-720.png (stored 0%)
#   adding: cropped/IMG-96.png (stored 0%)
#   adding: cropped/IMG-1346.png (stored 0%)
#   adding: cropped/IMG-1411.png (stored 0%)
#   adding: cropped/IMG-882.png (stored 0%)
#   adding: cropped/IMG-1760.png (stored 0%)
#   adding: cropped/IMG-1610.png (stored 0%)
#   adding: cropped/IMG-892.png (stored 0%)
#   adding: cropped/IMG-75.png (stored 0%)
#   adding: cropped/IMG-1764.png (deflated 1%)
#   adding: cropped/IMG-196.png (stored 0%)
#   adding: cropped/IMG-1120.png (stored 0%)
#   adding: cropped/IMG-728.png (stored 0%)
#   adding: cropped/IMG-258.png (stored 0%)
#   adding: cropped/IMG-1102.png (stored 0%)
#   adding: cropped/IMG-1803.png (deflated 2%)
#   adding: cropped/IMG-1214.png (stored 0%)
#   adding: cropped/IMG-506.png (stored 0%)
#   adding: cropped/IMG-1735.png (stored 0%)
#   adding: cropped/IMG-772.png (stored 0%)
#   adding: cropped/IMG-252.png (stored 0%)
#   adding: cropped/IMG-1117.png (stored 0%)
#   adding: cropped/IMG-635.png (stored 0%)
#   adding: cropped/IMG-464.png (stored 0%)
#   adding: cropped/IMG-958.png (stored 0%)
#   adding: cropped/IMG-71.png (stored 0%)
#   adding: cropped/IMG-1157.png (stored 0%)
#   adding: cropped/IMG-499.png (stored 0%)
#   adding: cropped/IMG-1288.png (stored 0%)
#   adding: cropped/IMG-370.png (stored 0%)
#   adding: cropped/IMG-1814.png (deflated 2%)
#   adding: cropped/IMG-1825.png (stored 0%)
#   adding: cropped/IMG-1248.png (stored 0%)
#   adding: cropped/IMG-1421.png (stored 0%)
#   adding: cropped/IMG-1151.png (stored 0%)
#   adding: cropped/IMG-1006.png (stored 0%)
#   adding: cropped/IMG-1659.png (stored 0%)
#   adding: cropped/IMG-1716.png (stored 0%)
#   adding: cropped/IMG-1456.png (stored 0%)
#   adding: cropped/IMG-1416.png (stored 0%)
#   adding: cropped/IMG-6.png (stored 0%)
#   adding: cropped/IMG-924.png (stored 0%)
#   adding: cropped/IMG-1083.png (stored 0%)
#   adding: cropped/IMG-1392.png (stored 0%)
#   adding: cropped/IMG-639.png (stored 0%)
#   adding: cropped/IMG-887.png (stored 0%)
#   adding: cropped/IMG-28.png (stored 0%)
#   adding: cropped/IMG-1437.png (stored 0%)
#   adding: cropped/IMG-1438.png (stored 0%)
#   adding: cropped/IMG-1377.png (stored 0%)
#   adding: cropped/IMG-1807.png (deflated 2%)
#   adding: cropped/IMG-441.png (stored 0%)
#   adding: cropped/IMG-188.png (stored 0%)
#   adding: cropped/IMG-1148.png (stored 0%)
#   adding: cropped/IMG-483.png (stored 0%)
#   adding: cropped/IMG-68.png (stored 0%)
#   adding: cropped/IMG-630.png (stored 0%)
#   adding: cropped/IMG-349.png (stored 0%)
#   adding: cropped/IMG-879.png (stored 0%)
#   adding: cropped/IMG-1727.png (stored 0%)
#   adding: cropped/IMG-1122.png (stored 0%)
#   adding: cropped/IMG-33.png (stored 0%)
#   adding: cropped/IMG-277.png (stored 0%)
#   adding: cropped/IMG-560.png (stored 0%)
#   adding: cropped/IMG-1780.png (stored 0%)
#   adding: cropped/IMG-1364.png (stored 0%)
#   adding: cropped/IMG-27.png (stored 0%)
#   adding: cropped/IMG-552.png (stored 0%)
#   adding: cropped/IMG-1136.png (stored 0%)
#   adding: cropped/IMG-828.png (stored 0%)
#   adding: cropped/IMG-1681.png (stored 0%)
#   adding: cropped/IMG-284.png (stored 0%)
#   adding: cropped/IMG-1757.png (stored 0%)
#   adding: cropped/IMG-1628.png (stored 0%)
#   adding: cropped/IMG-550.png (stored 0%)
#   adding: cropped/IMG-1789.png (stored 0%)
#   adding: cropped/IMG-1454.png (stored 0%)
#   adding: cropped/IMG-744.png (stored 0%)
#   adding: cropped/IMG-548.png (stored 0%)
#   adding: cropped/IMG-546.png (stored 0%)
#   adding: cropped/IMG-989.png (stored 0%)
#   adding: cropped/IMG-1736.png (stored 0%)
#   adding: cropped/IMG-678.png (stored 0%)
#   adding: cropped/IMG-1465.png (stored 0%)
#   adding: cropped/IMG-1189.png (stored 0%)
#   adding: cropped/IMG-394.png (stored 0%)
#   adding: cropped/IMG-361.png (stored 0%)
#   adding: cropped/IMG-1125.png (stored 0%)
#   adding: cropped/IMG-1375.png (stored 0%)
#   adding: cropped/IMG-1441.png (stored 0%)
#   adding: cropped/IMG-461.png (stored 0%)
#   adding: cropped/IMG-66.png (stored 0%)
#   adding: cropped/IMG-1721.png (stored 0%)
#   adding: cropped/IMG-1506.png (stored 0%)
#   adding: cropped/IMG-686.png (stored 0%)
#   adding: cropped/IMG-996.png (stored 0%)
#   adding: cropped/IMG-30.png (stored 0%)
#   adding: cropped/IMG-792.png (stored 0%)
#   adding: cropped/IMG-451.png (stored 0%)
#   adding: cropped/IMG-1187.png (stored 0%)
#   adding: cropped/IMG-1291.png (stored 0%)
#   adding: cropped/IMG-270.png (stored 0%)
#   adding: cropped/IMG-559.png (stored 0%)
#   adding: cropped/IMG-614.png (stored 0%)
#   adding: cropped/IMG-1205.png (stored 0%)
#   adding: cropped/IMG-1066.png (stored 0%)
#   adding: cropped/IMG-765.png (stored 0%)
#   adding: cropped/IMG-1332.png (stored 0%)
#   adding: cropped/IMG-825.png (stored 0%)
#   adding: cropped/IMG-1119.png (stored 0%)
#   adding: cropped/IMG-1182.png (stored 0%)
#   adding: cropped/IMG-813.png (stored 0%)
#   adding: cropped/IMG-1109.png (stored 0%)
#   adding: cropped/IMG-1338.png (stored 0%)
#   adding: cropped/IMG-1733.png (stored 0%)
#   adding: cropped/IMG-1289.png (stored 0%)
#   adding: cropped/IMG-1629.png (stored 0%)
#   adding: cropped/IMG-327.png (stored 0%)
#   adding: cropped/IMG-1268.png (stored 0%)
#   adding: cropped/IMG-1067.png (stored 0%)
#   adding: cropped/IMG-1692.png (stored 0%)
#   adding: cropped/IMG-399.png (stored 0%)
#   adding: cropped/IMG-1074.png (stored 0%)
#   adding: cropped/IMG-1751.png (stored 0%)
#   adding: cropped/IMG-1127.png (stored 0%)
#   adding: cropped/IMG-1224.png (stored 0%)
#   adding: cropped/IMG-634.png (stored 0%)
#   adding: cropped/IMG-521.png (stored 0%)
#   adding: cropped/IMG-955.png (stored 0%)
#   adding: cropped/IMG-1653.png (stored 0%)
#   adding: cropped/IMG-1113.png (stored 0%)
#   adding: cropped/IMG-495.png (stored 0%)
#   adding: cropped/IMG-295.png (stored 0%)
#   adding: cropped/IMG-570.png (stored 0%)
#   adding: cropped/IMG-1163.png (stored 0%)
#   adding: cropped/IMG-205.png (stored 0%)
#   adding: cropped/IMG-976.png (stored 0%)
#   adding: cropped/IMG-982.png (stored 0%)
#   adding: cropped/IMG-124.png (stored 0%)
#   adding: cropped/IMG-24.png (stored 0%)
#   adding: cropped/IMG-697.png (stored 0%)
#   adding: cropped/IMG-166.png (stored 0%)
#   adding: cropped/IMG-1244.png (stored 0%)
#   adding: cropped/IMG-1696.png (stored 0%)
#   adding: cropped/IMG-1142.png (stored 0%)
#   adding: cropped/IMG-387.png (stored 0%)
#   adding: cropped/IMG-14.png (stored 0%)
#   adding: cropped/IMG-1622.png (stored 0%)
#   adding: cropped/IMG-644.png (stored 0%)
#   adding: cropped/IMG-1146.png (stored 0%)
#   adding: cropped/IMG-1598.png (stored 0%)
#   adding: cropped/IMG-962.png (stored 0%)
#   adding: cropped/IMG-1211.png (stored 0%)
#   adding: cropped/IMG-877.png (stored 0%)
#   adding: cropped/IMG-305.png (stored 0%)
#   adding: cropped/IMG-1116.png (stored 0%)
#   adding: cropped/IMG-1052.png (stored 0%)
#   adding: cropped/IMG-247.png (stored 0%)
#   adding: cropped/IMG-1333.png (stored 0%)
#   adding: cropped/IMG-1294.png (stored 0%)
#   adding: cropped/IMG-1717.png (stored 0%)
#   adding: cropped/IMG-1124.png (stored 0%)
#   adding: cropped/IMG-988.png (stored 0%)
#   adding: cropped/IMG-127.png (stored 0%)
#   adding: cropped/IMG-854.png (stored 0%)
#   adding: cropped/IMG-1461.png (stored 0%)
#   adding: cropped/IMG-367.png (stored 0%)
#   adding: cropped/IMG-1280.png (stored 0%)
#   adding: cropped/IMG-1647.png (stored 0%)
#   adding: cropped/IMG-151.png (stored 0%)
#   adding: cropped/IMG-1069.png (stored 0%)
#   adding: cropped/IMG-522.png (stored 0%)
#   adding: cropped/IMG-561.png (stored 0%)
#   adding: cropped/IMG-695.png (stored 0%)
#   adding: cropped/IMG-1785.png (stored 0%)
#   adding: cropped/IMG-666.png (stored 0%)
#   adding: cropped/IMG-1105.png (stored 0%)
#   adding: cropped/IMG-1603.png (stored 0%)
#   adding: cropped/IMG-1321.png (stored 0%)
#   adding: cropped/IMG-1301.png (stored 0%)
#   adding: cropped/IMG-184.png (stored 0%)
#   adding: cropped/IMG-29.png (stored 0%)
#   adding: cropped/IMG-890.png (stored 0%)
#   adding: cropped/IMG-1614.png (stored 0%)
#   adding: cropped/IMG-1419.png (stored 0%)
#   adding: cropped/IMG-437.png (stored 0%)
#   adding: cropped/IMG-389.png (stored 0%)
#   adding: cropped/IMG-1769.png (deflated 2%)
#   adding: cropped/IMG-1612.png (stored 0%)
#   adding: cropped/IMG-516.png (stored 0%)
#   adding: cropped/IMG-307.png (stored 0%)
#   adding: cropped/IMG-789.png (stored 0%)
#   adding: cropped/IMG-1132.png (stored 0%)
#   adding: cropped/IMG-1345.png (stored 0%)
#   adding: cropped/IMG-874.png (stored 0%)
#   adding: cropped/IMG-1410.png (stored 0%)
#   adding: cropped/IMG-1796.png (deflated 2%)
#   adding: cropped/IMG-448.png (stored 0%)
#   adding: cropped/IMG-497.png (stored 0%)
#   adding: cropped/IMG-1308.png (stored 0%)
#   adding: cropped/IMG-1768.png (deflated 2%)
#   adding: cropped/IMG-837.png (stored 0%)
#   adding: cropped/IMG-1361.png (stored 0%)
#   adding: cropped/IMG-311.png (stored 0%)
#   adding: cropped/IMG-1422.png (stored 0%)
#   adding: cropped/IMG-264.png (stored 0%)
#   adding: cropped/IMG-1594.png (stored 0%)
#   adding: cropped/IMG-85.png (stored 0%)
#   adding: cropped/IMG-1687.png (stored 0%)
#   adding: cropped/IMG-1527.png (stored 0%)
#   adding: cropped/IMG-1210.png (stored 0%)
#   adding: cropped/IMG-1683.png (stored 0%)
#   adding: cropped/IMG-37.png (stored 0%)
#   adding: cropped/IMG-180.png (stored 0%)
#   adding: cropped/IMG-465.png (stored 0%)
#   adding: cropped/IMG-1772.png (deflated 3%)
#   adding: cropped/IMG-1462.png (stored 0%)
#   adding: cropped/IMG-1262.png (stored 0%)
#   adding: cropped/IMG-886.png (stored 0%)
#   adding: cropped/IMG-956.png (stored 0%)
#   adding: cropped/IMG-1080.png (stored 0%)
#   adding: cropped/IMG-1111.png (stored 0%)
#   adding: cropped/IMG-867.png (stored 0%)
#   adding: cropped/IMG-597.png (stored 0%)
#   adding: cropped/IMG-1578.png (stored 0%)
#   adding: cropped/IMG-276.png (stored 0%)
#   adding: cropped/IMG-787.png (stored 0%)
#   adding: cropped/IMG-1277.png (stored 0%)
#   adding: cropped/IMG-1436.png (stored 0%)
#   adding: cropped/IMG-917.png (stored 0%)
#   adding: cropped/IMG-128.png (stored 0%)
#   adding: cropped/IMG-100.png (stored 0%)
#   adding: cropped/IMG-880.png (stored 0%)
#   adding: cropped/IMG-1664.png (stored 0%)
#   adding: cropped/IMG-469.png (stored 0%)
#   adding: cropped/IMG-733.png (stored 0%)
#   adding: cropped/IMG-505.png (stored 0%)
#   adding: cropped/IMG-248.png (stored 0%)
#   adding: cropped/IMG-1633.png (stored 0%)
#   adding: cropped/IMG-518.png (stored 0%)
#   adding: cropped/IMG-940.png (stored 0%)
#   adding: cropped/IMG-466.png (stored 0%)
#   adding: cropped/IMG-844.png (stored 0%)
#   adding: cropped/IMG-746.png (stored 0%)
#   adding: cropped/IMG-676.png (stored 0%)
#   adding: cropped/IMG-1550.png (stored 0%)
#   adding: cropped/IMG-490.png (stored 0%)
#   adding: cropped/IMG-928.png (stored 0%)
#   adding: cropped/IMG-1382.png (stored 0%)
#   adding: cropped/IMG-1110.png (stored 0%)
#   adding: cropped/IMG-1480.png (stored 0%)
#   adding: cropped/IMG-62.png (stored 0%)
#   adding: cropped/IMG-1568.png (stored 0%)
#   adding: cropped/IMG-341.png (stored 0%)
#   adding: cropped/IMG-1586.png (stored 0%)
#   adding: cropped/IMG-34.png (stored 0%)
#   adding: cropped/IMG-471.png (stored 0%)
#   adding: cropped/IMG-796.png (stored 0%)
#   adding: cropped/IMG-1356.png (stored 0%)
#   adding: cropped/IMG-1239.png (stored 0%)
#   adding: cropped/IMG-362.png (stored 0%)
#   adding: cropped/IMG-1756.png (stored 0%)
#   adding: cropped/IMG-535.png (stored 0%)
#   adding: cropped/IMG-1282.png (stored 0%)
#   adding: cropped/IMG-1463.png (stored 0%)
#   adding: cropped/IMG-168.png (stored 0%)
#   adding: cropped/IMG-659.png (stored 0%)
#   adding: cropped/IMG-543.png (stored 0%)
#   adding: cropped/IMG-1811.png (stored 0%)
#   adding: cropped/IMG-1047.png (stored 0%)
#   adding: cropped/IMG-355.png (stored 0%)
#   adding: cropped/IMG-319.png (stored 0%)
#   adding: cropped/IMG-1380.png (stored 0%)
#   adding: cropped/IMG-32.png (stored 0%)
#   adding: cropped/IMG-1821.png (stored 0%)
#   adding: cropped/IMG-555.png (stored 0%)
#   adding: cropped/IMG-317.png (stored 0%)
#   adding: cropped/IMG-76.png (stored 0%)
#   adding: cropped/IMG-1503.png (stored 0%)
#   adding: cropped/IMG-778.png (stored 0%)
#   adding: cropped/IMG-1479.png (stored 0%)
#   adding: cropped/IMG-654.png (stored 0%)
#   adding: cropped/IMG-204.png (stored 0%)
#   adding: cropped/IMG-344.png (stored 0%)
#   adding: cropped/IMG-1809.png (stored 0%)
#   adding: cropped/IMG-566.png (stored 0%)
#   adding: cropped/IMG-1204.png (stored 0%)
#   adding: cropped/IMG-761.png (stored 0%)
#   adding: cropped/IMG-631.png (stored 0%)
#   adding: cropped/IMG-1390.png (stored 0%)
#   adding: cropped/IMG-900.png (stored 0%)
#   adding: cropped/IMG-222.png (stored 0%)
#   adding: cropped/IMG-383.png (stored 0%)
#   adding: cropped/IMG-532.png (stored 0%)
#   adding: cropped/IMG-605.png (stored 0%)
#   adding: cropped/IMG-926.png (stored 0%)
#   adding: cropped/IMG-42.png (stored 0%)
#   adding: cropped/IMG-1639.png (stored 0%)
#   adding: cropped/IMG-986.png (stored 0%)
#   adding: cropped/IMG-1016.png (stored 0%)
#   adding: cropped/IMG-486.png (stored 0%)
#   adding: cropped/IMG-616.png (stored 0%)
#   adding: cropped/IMG-1349.png (stored 0%)
#   adding: cropped/IMG-839.png (stored 0%)
#   adding: cropped/IMG-1103.png (stored 0%)
#   adding: cropped/IMG-1579.png (stored 0%)
# File ID: 1gXiQuQZM8ghq7q6i89jS9O0ca1JCsKqt
# {'id': '1gXiQuQZM8ghq7q6i89jS9O0ca1JCsKqt'}

# %% [markdown]
# The zip file is not on your google drive for you to uncompress and peruse.
